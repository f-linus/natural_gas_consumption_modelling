# %%
import os

os.chdir("../../")

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from src.data_handling import ingestion

sns.set_theme(context="paper", font_scale=1.15, style="whitegrid")

# %% [markdown]
# ### Temperatures

# %%
ingestion.read_temperatures().plot(figsize=(11, 1))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ### Imbalance prices

# %%
ncg_prices, gaspool_prices, the_prices = ingestion.read_imbalance_prices()
pd.concat([((gaspool_prices + ncg_prices) / 2), the_prices]).plot(figsize=(11, 1))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ### Crude oil prices

# %%
ingestion.read_crude_oil_prices().plot(figsize=(11, 1))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ### Electricity prices

# %%
ingestion.read_electricity_prices().plot(figsize=(11, 1))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ### EUA auctions

# %%
ingestion.read_eua_auctions().plot(figsize=(11, 1))
# Out:
# c:\Users\linus\anaconda3\envs\ba\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# c:\Users\linus\anaconda3\envs\ba\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# c:\Users\linus\anaconda3\envs\ba\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# c:\Users\linus\anaconda3\envs\ba\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# <Axes: >
